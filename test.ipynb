# %%
# %pip install openai sentence-transformers "chromadb==0.5.23" "numpy<2.0"
dbutils.library.restartPython()

# %%
import sys
sys.path.insert(0, "/Workspace/Users/ariamostajeran99@gmail.com/portfolio-assistant")

from ingestion.ingest_knowledge import ingest_all
ingest_all()

# %%
from ingestion.ingest_code import ingest_repo
ingest_repo("https://github.com/ariamostajeran/aria-portfolio")

# %%
from agent.assistant import PortfolioAgent

agent = PortfolioAgent()
print(agent.chat("Does Aria have experience with Docker?"))
print(agent.chat("Show me how the data fetcher works"))
print(agent.status())
